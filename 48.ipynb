# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.preprocessing import PowerTransformer

df = pd.read_csv('Data_to_Transform.csv')
df.head()
# Out:
#    Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                0.899990              2.895074               11.180748
# 1                1.113554              2.962385               10.842938
# 2                1.156830              2.966378               10.817934
# 3                1.264131              3.000324               10.764570
# 4                1.323914              3.012109               10.753117
#
#    Highly Negative Skew
# 0              9.027485
# 1              9.009762
# 2              9.006134
# 3              9.000125
# 4              8.981296

# %%
# вихідні дані
fig = sm.qqplot(df, line='45')
plt.show()

# %%
sns.histplot(df['Moderate Positive Skew'])
fig = plt.figure()

# %%
df_log_1 = np.log(df['Moderate Positive Skew'])
sns.histplot(df_log_1)
fig = plt.figure()

# %%
fig = sm.qqplot(df_log_1, line='45')
plt.show()

# %%
df_sqrt_1 = np.sqrt(df['Moderate Positive Skew'])
sns.histplot(df_sqrt_1)
fig = plt.figure()

# %%
fig = sm.qqplot(df_sqrt_1, line='45')
plt.show()

# %%
data_1 = df['Moderate Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_boxcox_1 = pt.fit_transform(data_1)
sns.histplot(df_boxcox_1)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox_1, line='45')
plt.show()

# %%
sns.histplot(df['Highly Positive Skew'])
fig = plt.figure()

# %%
df_log_2 = np.log(df['Highly Positive Skew'])
sns.histplot(df_log_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_log_2, line='45')
plt.show()

# %%
df_sqrt_2 = np.sqrt(df['Highly Positive Skew'])
sns.histplot(df_sqrt_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_sqrt_2, line='45')
plt.show()

# %%
data_2 = df['Highly Positive Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='box-cox')
df_boxcox_2 = pt.fit_transform(data_2)
sns.histplot(df_boxcox_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox_2, line='45')
plt.show()

# %%
sns.histplot(df['Moderate Negative Skew'])
fig = plt.figure()

# %%
df_cbrt_1 = np.cbrt(df['Moderate Negative Skew'])
sns.histplot(df_cbrt_1)
fig = plt.figure()

# %%
fig = sm.qqplot(df_cbrt_1, line='45')
plt.show()

# %%
df_2 = np.power(df['Moderate Negative Skew'], 2)
sns.histplot(df_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_2, line='45')
plt.show()

# %%
data_3 = df['Moderate Negative Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='yeo-johnson')
df_yeojohnson_1 = pt.fit_transform(data_3)
sns.histplot(df_yeojohnson_1)
fig = plt.figure()

# %%
fig = sm.qqplot(-df_yeojohnson_1, line='45')
plt.show()

# %%
sns.histplot(df['Highly Negative Skew'])
fig = plt.figure()

# %%
df_cbrt_2 = np.cbrt(df['Highly Negative Skew'])
sns.histplot(df_cbrt_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_cbrt_2, line='45')
plt.show()

# %%
df_3 = np.power(df['Moderate Negative Skew'], 2)
sns.histplot(df_3)
fig = plt.figure()

# %%
fig = sm.qqplot(df_3, line='45')
plt.show()

# %%
data_4 = df['Highly Negative Skew'].values.reshape(-1, 1)
pt = PowerTransformer(method='yeo-johnson')
df_yeojohnson_2 = pt.fit_transform(data_4)
sns.histplot(df_yeojohnson_2)
fig = plt.figure()

# %%
fig = sm.qqplot(-df_yeojohnson_2, line='45')
plt.show()

# %%
# Як висновок - найкраще з трансформацією даних до більш нормально розподілених справляється метод Бокса-Кокса та Йео-Джонсона
